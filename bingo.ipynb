# %%
import random
num = list(range(1,76))
yet = []
for i in range(74):
    a = random.choice(num)
    num.remove(a)
    yet.append(a)
    print(a)
    print(yet)
# Out:
# 58
# [58]
# 8
# [58, 8]
# 59
# [58, 8, 59]
# 31
# [58, 8, 59, 31]
# 10
# [58, 8, 59, 31, 10]
# 66
# [58, 8, 59, 31, 10, 66]
# 39
# [58, 8, 59, 31, 10, 66, 39]
# 57
# [58, 8, 59, 31, 10, 66, 39, 57]
# 1
# [58, 8, 59, 31, 10, 66, 39, 57, 1]
# 22
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22]
# 12
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12]
# 33
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33]
# 40
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40]
# 30
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40, 30]
# 46
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40, 30, 46]
# 49
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40, 30, 46, 49]
# 64
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40, 30, 46, 49, 64]
# 69
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40, 30, 46, 49, 64, 69]
# 56
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40, 30, 46, 49, 64, 69, 56]
# 29
# [58, 8, 59, 31, 10, 66, 39, 57, 1, 22, 12, 33, 40, 30, 46, 49, 64, 69, 56, 29]
# 18
# ...
